# %% [markdown]
# # Update this notebook as you complete the tasks, and a detailed explanation of the code or the concept is welcomed.
#
# # Mettre à jour ce notebook dès que vous completez vos tâches, et pensez à donner des explications	détaillées soit les codes ou les concepts pour qu'on comprenne bien facilement.
